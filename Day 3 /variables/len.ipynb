# %%
message="hello world"

# %%
print(len(message))
# Out:
# 11

# %%
len(message)
# Out:
# 11

# %%
print(message[0])
print(message[10])
print(message[11]) #len = n-1
# Out:
# h
# d
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 print(message[0])
#       2 print(message[10])
# ----> 3 print(message[11])
#
# IndexError: string index out of range

# %%
print(message[0:5])
print(message[6:11]) #the last index is excluded
# Out:
# hello
# world

# %%
print(message[0:11:2]) #3rd place is the increment
# Out:
# hlowrd

# %%
print(message[11:0:-1]) 
# -ve indicates counting in reverse order
# index starts from -1 to - infi
# Out:
# dlrow olle

# %%
message[1:11:3]
# Out:
# 'eood'
