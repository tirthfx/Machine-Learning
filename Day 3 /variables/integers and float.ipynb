# %%
#int = numbers
#float = decimals

# %%
num1=10
num2=4.12

# %%
print(type(num1))
print(type(num2))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(10+2)
print(10-2)
print(10*2)
print(10/2)

print(11**2)
print(11//2)
print(11%2)
# Out:
# 12
# 8
# 20
# 5.0
# 121
# 5
# 1

# %%
#order of opreations
print(3*2+1)
print(3*(2+1))
# Out:
# 7
# 9

# %%
num=1
num= num +1 
print(num)

num+= 1
print(num)
# Out:
# 2
# 3

# %%
#absolute value
print(abs(-2))
# Out:
# 2

# %%
print(round(3.142))

print(round(3.142,1))
# Out:
# 3
# 3.1

# %%
#comparison ops

print(num1==num2)
print(num1!=num2)
print(num1<num2)
print(num1>num2)
print(num1<=num2)
print(num1>=num2  )
# Out:
# False
# True
# False
# True
# False
# True

# %%
#casting
num3='200'
num4='243'

print(num3+num4)

#so

num3=int(num3)
num4=int(num4)
print(num3+num4)
# Out:
# 200243
# 443
